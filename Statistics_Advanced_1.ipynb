# %% [markdown]
# **Question 1 :-  What is a random variable in probability theory?**
#
# Answer 1 :- A random variable is a  function that assigns a numerical value to each possible outcome of a random experiment.
#
# Random Variable Has Two Types :- 1) Discrete Random Variable
#   2) Continuous Random Variable

# %% [markdown]
# **Question 2 :- What are the types of random variables?**
#
# Answer 2 :- Discrete Random Variable :- A discrete random variable takes countable values (finite or countably infinite).
#
# Examples :-
#
#
# *   Number of students present in a class
# *   Number of defective items in a batch
#
# Continuous Random Variable :- A continuous random variable takes any value within a given range.
#
# Examples:-
#
#
#
# *   Weight of a product
# *   Time taken to complete an exam

# %% [markdown]
# **Question 3: Explain the difference between discrete and continuous distributions.**
#
# Answer 3: Discrete Distribution :- A discrete distribution is associated with a discrete random variable, which takes countable and distinct values.
#
# some main points about discrete distriution is :-
#
#
# *   values can be finite or countably infinite
# *   Uses a Probability Mass Function (PMF)
#
#
# *   Total probability is the sum of probabilities and equals 1
#
# Example :-
#
#
# *   Number of heads in coin tosses
# *   Number of defective items in a batch
#
# Continuous Distribution :- A continuous distribution is associated with a continuous random variable, which can take any value within a given interval.
#
# some main points about continuous distribution :-
#
#
# *   Values are uncountable
# *   Probability of any exact value is zero
#
# *   Uses a Probability Density Function (PDF)
# *   Probabilities are calculated over intervals using integrals
#
# Examples :-
#
#
# *  Finding the probability that a person’s height lies between 160 cm and 170 cm involves calculating the area under the curve between these values.

# %% [markdown]
# **Question 4 :-  What is a binomial distribution, and how is it used in probability?**
#
# Answer 4 :- A binomial distribution is a discrete probability distribution that describes the probability of getting a certain number of successes in a fixed number of independent trials, where each trial has only two possible outcomes.
#
# The binomial distribution is widely used to model real-life situations involving yes/no outcomes, such as:
#
#
#
# *   Number of students who pass an exam
# *   Number of defective items in a batch

# %% [markdown]
# **Question 5:-  What is the standard normal distribution, and why is it important?**
#
#
# Answer 5 :-  A normal distribution is a continuous, bell-shaped probability distribution.
# When we standardize any normal distribution so that:
#
#
# *   Mean
# μ=0
# *  Standard deviation
# σ=1
#
#
#
# it becomes the standard normal distribution.
#
# importance of standard normal distributions are :-
#
#
#
# *   Simplifies Probability Calculations
# *   Allows Comparison of Different Data Sets

# %% [markdown]
# **Question 6:- What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
#
# Answer 6 :- The Central Limit Theorem (CLT) is one of the most important results in statistics. It explains why the normal distribution appears so often in real-world data analysis.
#
# CLT critical in statistics :-
#
#
# *   Makes Normal Distribution Applicable
# *   Foundation of Inferential Statistics
#
# *   Enables Real-World Data Analysis
# *   Simplifies Complex Problems

# %% [markdown]
# ** Question 7 :- What is the significance of confidence intervals in statistical analysis?**
#
# Answer 7 :-
#
# 1.   Measure of Precision
# 2.   Better Than Point Estimates
#
# 3.   Helps in Decision Making
# 4.   Used in Hypothesis Testing

# %% [markdown]
# **Question 8:- What is the concept of expected value in a probability distribution?**
#
# Answer 8 :- The expected value (EV) of a probability distribution is the long-run average outcome of a random variable if an experiment is repeated many times. It represents the theoretical mean of the distribution.
#
# expected value has two type :-
# 1. Point Value
# 2. Interval value

# %% [markdown]
# Question 9: Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate 1000 random numbers from normal distribution
data = np.random.normal(loc=50, scale=5, size=1000)

# Step 2: Compute mean and standard deviation
mean_value = np.mean(data)
std_value = np.std(data)

# Print results
print("Mean:", mean_value)
print("Standard Deviation:", std_value)

# Step 3: Plot histogram
plt.figure()
plt.hist(data, bins=30)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Normal Distribution (Mean=50, Std=5)")
plt.show()
# Out:
# Mean: 50.154659679386974
# Standard Deviation: 4.943018604696592

# %% [markdown]
# Question 10: You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.
#
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#  235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
# ● Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
#
# ● Write the Python code to compute the mean sales and its confidence interval

# %%
import numpy as np
from scipy import stats
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
sales = np.array(daily_sales)
mean_sales = np.mean(sales)
std_sales = np.std(sales, ddof=1)   # sample standard deviation
n = len(sales)
z = 1.96

standard_error = std_sales / np.sqrt(n)

# Confidence interval
lower_bound = mean_sales - z * standard_error
upper_bound = mean_sales + z * standard_error

# Print results
print("Mean Daily Sales:", mean_sales)
print("95% Confidence Interval:", (lower_bound, upper_bound))
# Out:
# Mean Daily Sales: 248.25
# 95% Confidence Interval: (np.float64(240.68312934041109), np.float64(255.81687065958891))
